# %% [markdown]
# # Validate Model Workflows in the Uncertainty Engine SDK

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](
# https://colab.research.google.com/github/digiLab-ai/ue-sdk-helper/blob/main/notebooks/05_validate_model_workflow.ipynb)
#
# In this notebook, we go through how to validate a trained model in the SDK.

# %% [markdown]
# ## 1. Setup

# %% [markdown]
# We start by installing the Uncertainty Engine:

# %%
# !pip install --quiet uncertainty-engine

# %% [markdown]
# And then make our imports:

# %%
from uncertainty_engine import Client
import os

# %% [markdown]
# We have different methods for interacting with our Uncertainty Engine username and password depending on whether you are using Google Colab or a local python install.
#
# Please update the following accordingly:

# %%
is_google_colab = False
is_local = not is_google_colab

# %% [markdown]
# ### Option A: Google Colab

# %% [markdown]
# On the left, click on the key (<img src=data:image/png;base64,... width="20"/>). Select `+ Add new secret`.
#
# Then, fill in:
#
# *   ```UE_USERNAME```: your Uncertainty Engine username (email address),
# *   ```UE_PASSWORD```: your Uncertainty Engine password.
#
# It should look like:
#
# <img src=data:image/png;base64,... width="500"/>

# %%
if is_google_colab:
    from google.colab import userdata

    os.environ["UE_PASSWORD"] = userdata.get("UE_PASSWORD")
    os.environ["UE_USERNAME"] = userdata.get("UE_USERNAME")

# %% [markdown]
# ### Option B: Local Use

# %% [markdown]
# In the *root* directory of your project, make a file named `.env`. Populate the file with:
#
# ```
# UE_USERNAME='your_username'
# UE_PASSWORD='your_password'
# ```

# %% [markdown]
# Next, make sure that your secrets are never git committed. You can do this by adding `.env` to the `.gitignore` file in your project root directory:
# ```
# .env
# ```

# %% [markdown]
# Then load dotenv:

# %%
if is_local:
    # !pip install --quiet python-dotenv
    from dotenv import load_dotenv
    # automatically load .env in current directory
    load_dotenv()
# Out:
# True

# %% [markdown]
# ### Initialise your Uncertainty Engine client.

# %%
client = Client()

# %%
client.authenticate(os.environ["UE_ACCOUNT_ID"])
# Out:
# /var/folders/dn/cm037cfs6x91lt40wn_cx_6c0000gn/T/ipykernel_9643/2509143929.py:1: DeprecationWarning: The 'account_id' parameter is deprecated and will be removed in the next release. Fetching account ID from HTTP headers instead.
#   client.authenticate(os.environ["UE_ACCOUNT_ID"])

# %% [markdown]
# Now we have told the Uncertainty Engine who we are, we can specify which project we are working on.

# %%
PROJECT_NAME = "Demos"

# %% [markdown]
# ## 2. Train Model Workflow

# %% [markdown]
# We are targetting making the below workflow to train a probabilistic machine learning model. This can be created in the GUI and directly interacted with in the SDK, however in this notebook we explicitly create the workflow in the SDK.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 2.a. Making/importing helper functions

# %% [markdown]
# The Uncertainty Engine follows a graph-based structure. For the purpose of this notebook, we will wrap the workflow as a function to demonstrate how it can be encorporated into existing workflows.

# %%
# imports
from pprint import pprint
from uncertainty_engine.nodes.base import Node
from uncertainty_engine.graph import Graph
from uncertainty_engine.nodes.workflow import Workflow

import numpy as np
import pandas as pd
import io

# %% [markdown]
# Helper functions:

# %%
# The helper functions developed in earlier notebooks.

from uncertainty_engine_types import ResourceID

def get_project_id(client, project_name: str) -> str:
    """
    Get the project ID from the project name.
    :param client: The Uncertainty Engine client.
    :param project_name: The name of the project.
    return: The project ID.
    """
    projects = client.projects.list_projects()
    for project in projects:
        if project.name == project_name:
            return project.id
    raise ValueError(f"Project with name {project_name} not found.")


def get_resource_id(client, project_name: str, resource_name: str, resource_type: str) -> str:
    """
    Get the resource ID from the workflow name.
    :param client: The Uncertainty Engine client.
    :param project_name: The name of the project.
    :param resource_name: The name of the resource.
    :param resource_type: The type of the resource (e.g., 'dataset', 'model', ...).
    return: The resource ID.
    """
    project_id = get_project_id(client, project_name)
    resources = client.resources.list_resources(project_id, resource_type=resource_type)
    for resource in resources:
        if resource.name == resource_name:
            return resource.id
    raise ValueError(f"Resource with name {resource_name} not found.")

def upload_dataset(client, project_name, dataset_name, file_path=None, dataset=None, is_replace=True):
    PROJECT_ID = get_project_id(client, project_name)
    if file_path is None and dataset is not None:

        file_path = f'{dataset_name}.csv'

        df = pd.DataFrame(dataset)
        df.to_csv(file_path, index=False)
    elif file_path is None and dataset is None:
        raise ValueError("Either file_path or dataset must be provided.")
    PROJECT_ID = get_project_id(client, project_name)
    try:
        client.resources.upload(
            project_id=PROJECT_ID,
            name=dataset_name,
            resource_type="dataset",
            file_path=file_path,
        )
    except Exception as e:
        if is_replace:
            client.resources.update(
                project_id=PROJECT_ID,
                resource_id=get_resource_id(client, project_name, dataset_name, resource_type="dataset"),
                resource_type="dataset",
                file_path=file_path,
            )
        else:
            print(f"Error uploading dataset: {e}")
    print(f'Uploaded {dataset_name} to {project_name}')

def wrap_resource_id(resource_id: str):
    """
    Wrap a resource ID in a ResourceID object and return its dictionary representation.
    :param resource_id: The resource ID to wrap.
    :return: The dictionary representation of the ResourceID object."""
    return ResourceID(id=resource_id).model_dump()

def get_data(client,
             project_name: str,
             dataset_name: str,):
    """
    Download a dataset from the Uncertainty Engine and return it as a pandas DataFrame.
    :param client: The Uncertainty Engine client.
    :param project_name: The name of the project.
    :param dataset_name: The name of the dataset.
    :return: The dataset as a pandas DataFrame.
    """
    response = client.resources.download(
            project_id=get_project_id(client=client, project_name=project_name),
            resource_type='dataset',
            resource_id=get_resource_id(client=client, project_name=project_name,
                                resource_name=dataset_name, resource_type='dataset')
        )
    decoded = response.decode("utf-8")
    df = pd.read_csv(io.StringIO(decoded))
    return df

def get_node_info(client, node_name):
    nodes = client.list_nodes()
    nodes_by_id = {node["id"]: node for node in nodes}
    # Print the details of the node
    pprint(nodes_by_id[node_name])

# %% [markdown]
# Visualisation:

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap, Normalize

KEY_LIME = "#EBF38B"; INDIGO = "#16425B"; KEPPEL = "#16D5C2"
colors = [KEY_LIME, KEPPEL, INDIGO]
cmap_std = LinearSegmentedColormap.from_list("custom_map", colors)

def _infer_shape(x0, x1):
    # Sort by (x0, x1) to ensure a consistent grid ordering
    order = np.lexsort((x1, x0))
    x0s, x1s = x0[order], x1[order]
    # Unique counts along each axis
    nx = np.unique(x0s).size
    ny = np.unique(x1s).size
    return (ny, nx), order

def _shared_norm_for_column(gt, pred):
    vmin = np.nanmin([np.nanmin(gt), np.nanmin(pred)])
    vmax = np.nanmax([np.nanmax(gt), np.nanmax(pred)])
    if np.isclose(vmin, vmax):
        # Avoid zero-range norms
        eps = 1e-9 if vmax == 0 else 1e-3 * abs(vmax)
        vmin, vmax = vmin - eps, vmax + eps
    return Normalize(vmin=vmin, vmax=vmax)

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap, Normalize

# --- your palette & cmap
KEY_LIME = "#EBF38B"; INDIGO = "#16425B"; KEPPEL = "#16D5C2"
cmap_std = LinearSegmentedColormap.from_list("custom_map", [KEY_LIME, KEPPEL, INDIGO])

def _infer_shape(x0, x1):
    order = np.lexsort((np.asarray(x1), np.asarray(x0)))
    x0s, x1s = np.asarray(x0)[order], np.asarray(x1)[order]
    nx = np.unique(x0s).size
    ny = np.unique(x1s).size
    return (ny, nx), order

def _shared_norm(gt, pr):
    vmin = np.nanmin([gt.min(), pr.min()])
    vmax = np.nanmax([gt.max(), pr.max()])
    if np.isclose(vmin, vmax):
        eps = 1e-9 if vmax == 0 else 1e-3 * abs(vmax)
        vmin, vmax = vmin - eps, vmax + eps
    return Normalize(vmin=vmin, vmax=vmax)

def plot_results_grid(
    test_inputs,
    test_prediction,
    test_uncertainty,
    test_outputs,
    training_inputs=None,              # DataFrame with columns ['x0','x1'] for scatter
    input_cols=("x0", "x1"),
    output_cols=None,
    shape=None,
    cmap=cmap_std,
    suptitle=None,
    figsize_per_col=3.2,
    figsize_row=3.0,
    scatter_kwargs=None,               # to tweak training points (size, alpha, etc.)
):
    """
    Grid: rows=[Ground truth, Prediction, Uncertainty], cols=each output in output_cols.
    - Top colorbars with labels
    - Column headers (output names) placed above colorbars, just below suptitle
    - Optional white scatter points for training_inputs across all panels
    """
    import pandas as pd

    x0 = np.asarray(test_inputs[input_cols[0]])
    x1 = np.asarray(test_inputs[input_cols[1]])
    if output_cols is None:
        output_cols = list(test_outputs.columns)

    if shape is None:
        shape, order = _infer_shape(x0, x1)
        x0 = x0[order]; x1 = x1[order]
        test_outputs = test_outputs.iloc[order]
        test_prediction = test_prediction.iloc[order]
        test_uncertainty = test_uncertainty.iloc[order]
    ny, nx = shape

    X = x0.reshape(ny, nx)
    Y = x1.reshape(ny, nx)

    n_cols = len(output_cols)
    n_rows = 3
    fig_w = max(8, n_cols * figsize_per_col)
    fig_h = max(6, n_rows * figsize_row)
    fig, axs = plt.subplots(n_rows, n_cols, figsize=(fig_w, fig_h), squeeze=False, constrained_layout=True)

    row_titles = ["Ground truth", "Prediction", "Uncertainty"]

    # norms per column (GT/Pred share), uncertainty separate
    col_norms = []
    unc_norms = []
    for yname in output_cols:
        gt = np.asarray(test_outputs[yname])
        pr = np.asarray(test_prediction[yname])
        un = np.asarray(test_uncertainty[yname])
        col_norms.append(_shared_norm(gt, pr))

        umin, umax = np.nanmin(un), np.nanmax(un)
        if np.isclose(umin, umax):
            eps = 1e-9 if umax == 0 else 1e-3 * abs(umax)
            umin, umax = umin - eps, umax + eps
        unc_norms.append(Normalize(vmin=umin, vmax=umax))

    # default scatter style for training points
    skwargs = dict(s=14, c="white", edgecolors="white", linewidths=0.6, alpha=0.95, zorder=5)
    if scatter_kwargs:
        skwargs.update(scatter_kwargs)

    # plotting
    for c, yname in enumerate(output_cols):
        # Column header (place it high so it sits above the colorbar)
        axs[0, c].set_title(yname, y=1.5, fontsize=11)

        # ---- Row 0: Ground truth
        Z = np.asarray(test_outputs[yname]).reshape(ny, nx)
        im0 = axs[0, c].pcolormesh(X, Y, Z, cmap=cmap, shading="auto", norm=col_norms[c])
        cb0 = fig.colorbar(im0, ax=axs[0, c], orientation="horizontal", location="top", pad=-0.5)
        cb0.set_label(row_titles[0])

        # ---- Row 1: Prediction
        Z = np.asarray(test_prediction[yname]).reshape(ny, nx)
        im1 = axs[1, c].pcolormesh(X, Y, Z, cmap=cmap, shading="auto", norm=col_norms[c])
        cb1 = fig.colorbar(im1, ax=axs[1, c], orientation="horizontal", location="top", pad=0.)
        cb1.set_label(row_titles[1])

        # ---- Row 2: Uncertainty
        Z = np.asarray(test_uncertainty[yname]).reshape(ny, nx)
        im2 = axs[2, c].pcolormesh(X, Y, Z, cmap=cmap, shading="auto", norm=unc_norms[c])
        cb2 = fig.colorbar(im2, ax=axs[2, c], orientation="horizontal", location="top", pad=0.)
        cb2.set_label(row_titles[2])

        # overlay training inputs scatter (if provided)
        if training_inputs is not None:
            # axs[0, c].scatter(training_inputs[input_cols[0]], training_inputs[input_cols[1]], **skwargs)
            # axs[1, c].scatter(training_inputs[input_cols[0]], training_inputs[input_cols[1]], **skwargs)
            axs[2, c].scatter(training_inputs[input_cols[0]], training_inputs[input_cols[1]], label='Training data', **skwargs)

        # axis labels on left & bottom to reduce clutter
        if c == 0:
            axs[0, c].set_ylabel(input_cols[1])
            axs[1, c].set_ylabel(input_cols[1])
            axs[2, c].set_ylabel(input_cols[1])
        axs[2, c].set_xlabel(input_cols[0])

    if training_inputs is not None:
        axs[2, 0].legend(loc="upper right", frameon=True)
        axs[2, 1].legend(loc="upper right", frameon=True)
    if suptitle:
        fig.suptitle(suptitle, y=0.98, fontsize=12)

    return fig, axs

# %% [markdown]
# Main train and save workflow:

# %%
def train_and_save_model_workflow(client, 
                   project_name: str,
                   dataset_name: str, 
                   input_names: list,
                   output_names: list,
                   save_model_name: str,
                   is_visualise_workflow: bool = False,
                   is_print_full_output: bool = False) -> dict:
    """
    A workflow that trains a machine learning model.
    Here, we assume all resources have already been uploaded to the cloud.
    :param client: The Uncertainty Engine client.
    :param project_name: The name of the project.
    :param dataset_name: The name of the dataset.
    :param input_names: The names of the input columns.
    :param output_names: The names of the output columns.
    :param save_model_name: The name to save the trained model as.
    :param is_visualise_workflow: Whether to print the workflow graph.
    :param is_print_full_output: Whether to print the full output of the workflow.
    :return: The response from running the workflow.
    """
    # 1. Create the graph
    graph = Graph()

    # 2. Create relevant nodes, handles, and add to graph:

    # 2.a. Model config node
    model_config = Node(
        node_name="ModelConfig",
        label="Model Config",
    )
    graph.add_node(model_config)  # add to graph
    output_config = model_config.make_handle("config")  # add handle
    
    # 2.b. Load dataset node
    load_data = Node(
        node_name="LoadDataset",
        label="Load Dataset",
        file_id=wrap_resource_id(
            get_resource_id(
                client=client,
                project_name=project_name, 
                resource_name=dataset_name, 
                resource_type='dataset')
                ),
        project_id=get_project_id(
            client=client,
            project_name=project_name
            ),
    )
    graph.add_node(load_data)  # add to graph
    dataset = load_data.make_handle("full_dataset")  # add handle
    
    # 2.b. Filter dataset node for inputs
    input_data = Node(
        node_name="FilterDataset",
        label="Input Dataset",
        columns=input_names,
        dataset=dataset,
    )
    graph.add_node(input_data)  # add to graph
    input_dataset = load_data.make_handle("input_dataset")  # add handle
    
    # 2.c. Filter dataset node for outputs
    output_data = Node(
        node_name="FilterDataset",
        label="Output Dataset",
        columns=output_names,
        dataset=dataset,
    )
    graph.add_node(output_data)  # add to graph
    output_dataset = load_data.make_handle("output_dataset")  # add handle
    
    # 2.d. Train model node
    train_model = Node(
        node_name="TrainModel",
        label="Train Model",
        config=output_config,
        inputs=input_dataset,
        outputs=output_dataset,
    )
    graph.add_node(train_model)  # add to graph
    output_model = train_model.make_handle("model")  # add handle
    
    # 2.e. Save model node
    save = Node(
        node_name="Save",
        label="Save",
        file=output_model,
        fileid=save_model_name,
    )
    graph.add_node(save)  # add to graph

    if is_visualise_workflow:
        pprint(graph.nodes)

    workflow = Workflow(
        graph=graph.nodes,
        inputs=graph.external_input,
        external_input_id=graph.external_input_id,
        requested_output={
            }
        )

    response = client.run_node(workflow)
    if is_print_full_output:
        pprint(response.model_dump())

# %% [markdown]
# ### 2.b. Data Generation

# %%
def make_outputs_base(X, output_names):
    """
    Compute outputs deterministically from inputs X).
    Uses simple example rules cycling over inputs:
      y0 = sin(x)
      y1 = x^2
      y2 = exp(-0.1*x)
    """
    in_cols = list(X.columns)
    df = X.copy()

    for j, name in enumerate(output_names):
        x = df[in_cols[j % len(in_cols)]].to_numpy()
        if j % 3 == 0:
            y = np.sin(x)
        elif j % 3 == 1:
            y = x**2
        else:
            y = np.exp(-0.1 * x)
        df[name] = y
    return df

def make_data(input_names, output_names, filepath, n_points=100, seed=None,
              noise_std_cycle=(0.1, 1.0, 0.05), return_arrays=False):
    """
    Generate a synthetic dataset:
      - Builds inputs (linspace, uniform, normal cycling)
      - Calls deterministic base mapping
      - Adds Gaussian noise with stds cycling in noise_std_cycle
      - Saves to CSV
    """
    rng = np.random.default_rng(seed)

    # --- Inputs (simple defaults) ---
    X = {}
    for i, name in enumerate(input_names):
        if i % 3 == 0:
            X[name] = np.linspace(0, 10, n_points)
        elif i % 3 == 1:
            X[name] = rng.uniform(-5, 5, n_points)
        else:
            X[name] = rng.normal(0, 2, n_points)
    X = pd.DataFrame(X)

    # --- Deterministic outputs (noiseless) ---
    df_noiseless = make_outputs_base(X, output_names)

    # --- Add Gaussian noise ---
    df = df_noiseless.copy()
    for j, name in enumerate(output_names):
        std = noise_std_cycle[j % len(noise_std_cycle)]
        df[name] = df_noiseless[name] + rng.normal(0, std, n_points)

    # --- Save ---
    df.to_csv(filepath, index=False)

    if return_arrays:
        return df, df[input_names].to_numpy(), df[output_names].to_numpy()
    return df

# %% [markdown]
# To replicate a sparse dataset, we will train with just 20 data points.

# %%
input_names = ["x0", "x1"] 
output_names = ["y0", "y1"]
filename = "example"
filepath = f"{filename}.csv"
n_points = 20
make_data(input_names=input_names, 
          output_names=output_names, 
          filepath=filepath,
          n_points=n_points)
# Out:
#            x0        x1        y0         y1
# 0    0.000000 -0.281775  0.027454   0.227984
# 1    0.526316 -3.191762  0.444733  11.422199
# 2    1.052632  1.351851  0.817226   2.918663
# 3    1.578947  4.337597  0.830135  18.849136
# 4    2.105263 -1.269132  0.880050   3.276373
# 5    2.631579 -0.033989  0.416048  -0.042405
# 6    3.157895 -2.489669 -0.101505   6.637285
# 7    3.684211  3.039175 -0.723275   9.627058
# 8    4.210526 -4.730477 -0.910132  22.169729
# 9    4.736842  2.088735 -0.870211   4.620643
# 10   5.263158 -3.956542 -0.781249  14.952247
# 11   5.789474 -1.067295 -0.608004   0.266353
# 12   6.315789 -0.253353  0.100101   0.829591
# 13   6.842105 -0.453709  0.649886   0.215862
# 14   7.368421  2.045423  1.013415   5.194797
# 15   7.894737 -2.057017  1.232985   2.836121
# 16   8.421053  1.787273  0.797079   4.974653
# 17   8.947368  2.576038  0.598269   7.550826
# 18   9.473684  0.781214 -0.173645   1.294144
# 19  10.000000  0.702181 -0.613492   1.597675

# %% [markdown]
# ### 2.c. Uploading Training Data to Cloud

# %%
upload_dataset(client=client,
               project_name=PROJECT_NAME,
               dataset_name=filename,
               file_path=filepath,
               is_replace=True)
# Out:
# Uploaded example to Demos

# %% [markdown]
# ### 2.d. Training Probabilistic Machine Learning Model

# %%
train_and_save_model_workflow(client, 
                   project_name=PROJECT_NAME,
                   dataset_name=filename, 
                   input_names=input_names,
                   output_names=output_names,
                   save_model_name=f'{filename}_model',
                   is_print_full_output=True
                   )
# Out:
# {'inputs': {'external_input_id': '_',
#             'graph': {'nodes': {'Input Dataset': {'inputs': {'columns': {'node_handle': 'Input '
#                                                                                         'Dataset_columns',
#                                                                          'node_name': '_'},
#                                                              'dataset': {'node_handle': 'full_dataset',
#                                                                          'node_name': 'Load '
#                                                                                       'Dataset'}},
#                                                   'type': 'FilterDataset'},
#                                 'Load Dataset': {'inputs': {'file_id': {'node_handle': 'Load '
#                                                                                        'Dataset_file_id',
#                                                                         'node_name': '_'},
#                                                             'project_id': {'node_handle': 'Load '
#                                                                                           'Dataset_project_id',
#                                                                            'node_name': '_'}},
#                                                  'type': 'LoadDataset'},
#                                 'Model Config': {'inputs': {},
#                                                  'type': 'ModelConfig'},
#                                 'Output Dataset': {'inputs': {'columns': {'node_handle': 'Output '
#                                                                                          'Dataset_columns',
#                                                                           'node_name': '_'},
#                                                               'dataset': {'node_handle': 'full_dataset',
#                                                                           'node_name': 'Load '
#                                                                                        'Dataset'}},
#                                                    'type': 'FilterDataset'},
#                                 'Save': {'inputs': {'file': {'node_handle': 'model',
#                                                              'node_name': 'Train '
#                                                                           'Model'},
#                                                     'fileid': {'node_handle': 'Save_fileid',
#                                                                'node_name': '_'}},
#                                          'type': 'Save'},
#                                 'Train Model': {'inputs': {'config': {'node_handle': 'config',
#                                                                       'node_name': 'Model '
#                                                                                    'Config'},
#                                                            'inputs': {'node_handle': 'input_dataset',
#                                                                       'node_name': 'Load '
#                                                                                    'Dataset'},
#                                                            'outputs': {'node_handle': 'output_dataset',
#                                                                        'node_name': 'Load '
#                                                                                     'Dataset'}},
#                                                 'type': 'TrainModel'}}},
#             'inputs': {'Input Dataset_columns': ['x0', 'x1'],
#                        'Load Dataset_file_id': {'id': '68dfc0f3e889afed3bc9427e'},
#                        'Load Dataset_project_id': '68dfc0b9e889afed3bc9427d',
#                        'Output Dataset_columns': ['y0', 'y1'],
#                        'Save_fileid': 'example_model'},
#             'requested_output': {}},
#  'message': "Execution failed: Command '['bash', './scripts/entrypoint.sh']' "
#             'returned non-zero exit status 1.\n'
#             'Node stdout: Running node\n'
#             'Running node Model Config\n'
#             'Preparing to call and wait for node:\n'
#             '\n'
#             "id='ModelConfig' label='Model Config' "
#             "category='MachineLearningModels' description='Config for a "
#             "machine learning model' long_description='Config for a machine "
#             "learning model' image_name='uncertainty-engine-model-config-node' "
#             "cost=1 inputs={'input_variance': NodeInputInfo(type='float', "
#             "label='Input Variance', description='Percentage of variance to "
#             "retain in the input data', required=False, set_in_node=True, "
#             "default=None), 'input_retained_dimensions': "
#             "NodeInputInfo(type='int', label='Input Retained Dimensions', "
#             "description='Number of dimensions to retain in the input data', "
#             'required=False, set_in_node=True, default=None), '
#             "'output_variance': NodeInputInfo(type='float', label='Output "
#             "Variance', description='Percentage of variance to retain in the "
#             "output data', required=False, set_in_node=True, default=None), "
#             "'output_retained_dimensions': NodeInputInfo(type='int', "
#             "label='Output Retained Dimensions', description='Number of "
#             "dimensions to retain in the output data', required=False, "
#             "set_in_node=True, default=None), 'model_type': "
#             'NodeInputInfo(type=\'Literal["BernoulliClassificationGPTorch", '
#             '"SingleTaskGPTorch", "SingleTaskVariationalGPTorch"]\', '
#             "label='Model Type', description='Type of model to use', "
#             "required=False, set_in_node=True, default='SingleTaskGPTorch'), "
#             "'kernel': NodeInputInfo(type='Optional[str]', label='Kernel', "
#             "description='Type of kernel to use for the model', "
#             "required=False, set_in_node=True, default=None), 'warp_inputs': "
#             "NodeInputInfo(type='bool', label='Warp Inputs', "
#             "description='Whether to warp the inputs for the model', "
#             "required=False, set_in_node=True, default=False), 'seed': "
#             "NodeInputInfo(type='Optional[int]', label='Seed', "
#             "description='Seed for  reproducible training', required=False, "
#             "set_in_node=True, default=None)} outputs={'config': "
#             "NodeOutputInfo(type='ModelConfig', label='Model Config', "
#             "description='A model config object')} "
#             'requirements=NodeRequirementsInfo(cpu=256, gpu=False, memory=512, '
#             'timeout=15) '
#             "load_balancer_url='http://prod-u-uncer-qcwJx3w1EKiN-533598857.eu-west-2.elb.amazonaws.com' "
#             "queue_url='https://sqs.eu-west-2.amazonaws.com/939027885851/prod-uncertainty-engine-model-con-uncertaintyenginemodelconfignodeQ-GUJsRzjQakHD' "
#             "cache_url='redis-13325.c338.eu-west-2-1.ec2.redns.redis-cloud.com' "
#             "version_types_lib='0.4.0' version_base_image=2 version_node=0 "
#             '(Node ID = "ModelConfig")\n'
#             'Enqueuing job via HTTP '
#             '(http://prod-u-uncer-qcwJx3w1EKiN-533598857.eu-west-2.elb.amazonaws.com/queue):\n'
#             '\n'
#             "{'inputs': {}, 'nodes': {'Add': {'id': 'Add', 'label': 'Add', "
#             "'category': 'Basic', 'description': 'Sum two numbers', "
#             "'long_description': 'Add two numbers together', 'image_name': "
#             "'uncertainty-engine-add-node', 'cost': 1, 'inputs': {'lhs': "
#             "{'type': 'float', 'label': 'LHS', 'description': 'Left-hand side "
#             "of the addition', 'required': True, 'set_in_node': True, "
#             "'default': None}, 'rhs': {'type': 'float', 'label': 'RHS', "
#             "'description': 'Right-hand side of the addition', 'required': "
#             "True, 'set_in_node': True, 'default': None}}, 'outputs': {'ans': "
#             "{'type': 'float', 'label': 'Answer', 'description': 'Result of "
#             "the addition'}}, 'requirements': {'cpu': 256, 'gpu': False, "
#             "'memory': 512, 'timeout': 15}, 'load_balancer_url': "
#             "'http://prod-u-uncer-8Dm4BCeDOhUv-2026795141.eu-west-2.elb.amazonaws.com', "
#             "'queue_url': "
#             "'https://sqs.eu-west-2.amazonaws.com/939027885851/prod-uncertainty-engine-add-node-uncertaintyengineaddnodeQueueFF3B1-7VhRgceGZMHS', "
#             "'cache_url': "
#             "'redis-13325.c338.eu-west-2-1.ec2.redns.redis-cloud.com', "
#             "'version_types_lib': '0.4.0', 'version_base_image': 2, "
#             "'version_node': 3}, 'LoadDocument': {'id': 'LoadDocument', "
#             "'label': 'Document', 'category': 'Input', 'description': 'Load a "
#             "document', 'long_description': 'Load a saved document to use "
#             "within your workflow.', 'image_name': "
#             "'uncertainty-engine-load-document-node', 'cost': 1, 'inputs': "
#             "{'project_id': {'type': 'str', 'label': 'Project ID', "
#             "'description': 'Project ID', 'required': True, 'set_in_node': "
#             "True, 'default': None}, 'file_id': {'type': 'ResourceID', "
#             "'label': 'File ID', 'description': 'File ID', 'required': True, "
#             "'set_in_node': True, 'default': None}}, 'outputs': {'file': "
#             "{'type': 'Document', 'label': 'Document', 'description': 'A "
#             "loaded document'}}, 'requirements': {'cpu': 1024, 'gpu': False, "
#             "'memory': 2048, 'timeout': 180}, 'load_balancer_url': "
#             "'http://prod-u-uncer-dntXVhIwipYc-40087431.eu-west-2.elb.amazonaws.com', "
#             "'queue_url': "
#             "'https://sqs.eu-west-2.amazonaws.com/939027885851/prod-uncertainty-engine-load-docu-uncertaintyengineloaddocumentnode-4wsyyCgdJlvc', "
#             "'cache_url': "
#             "'redis-13325.c338.eu-west-2-1.ec2.redns.redis-cloud.com', "
#             "'version_types_lib': '0.4.0', 'version_base_image': 2, "
#             "'version_node': 0}, 'PromptLLM': {'id': 'PromptLLM', 'label': "
#             "'Prompt LLM', 'category': 'Agentic', 'description': 'Prompt a "
#             "Large Language Model to output a response', 'long_description': "
#             "'This node allows you to construct a system instruction, with "
#             'context, alongside a list of messages for a large language model '
#             "to process and respond to.', 'image_name': "
#             "'uncertainty-engine-prompt-l-l-m-node', 'cost': 10, 'inputs': "
#             "{'instruction': {'type': 'str', 'label': 'Instruction Prompt', "
#             "'description': 'System message to instruct the model to perform a "
#             'specific task or behave in a particular way. In this template, '
#             'you can include additional content in the `context` dictionary '
#             "below.', 'required': True, 'set_in_node': True, 'default': None}, "
#             "'chat_history': {'type': 'Optional[ChatHistory]', 'label': 'Chat "
#             'History\', \'description\': "Chat history to pass to the model. '
#             "This is a list of messages with the 'role', 'content' and "
#             '\'timestamp\' keys.", \'required\': False, \'set_in_node\': '
#             "False, 'default': None}, 'context': {'type': 'Optional[dict[str, "
#             "Any]]', 'label': 'Context', 'description': 'Additional context to "
#             'pass to the model. All items relate to the variables in the '
#             "instruction prompt to the model.', 'required': False, "
#             "'set_in_node': False, 'default': None}, 'output_structure': "
#             "{'type': 'Optional[dict[str, dict]]', 'label': 'Output "
#             "Structure', 'description': 'The structure of the output response. "
#             'If not provided, the output defaults to a string. If provided, '
#             "the output will be a dictionary with the specified keys.', "
#             "'required': False, 'set_in_node': False, 'default': None}, "
#             "'config': {'type': 'LLMConfig', 'label': 'LLM Config', "
#             "'description': 'Model selection and credentials for the LLM.', "
#             "'required': True, 'set_in_node': False, 'default': None}, "
#             "'number_of_retries': {'type': 'int', 'label': 'Number of "
#             "Retries', 'description': 'Number of times to retry the request if "
#             "it fails.', 'required': False, 'set_in_node': True, 'default': "
#             "5}}, 'outputs': {'response': {'type': 'dict[str, str]', 'label': "
#             '\'LLM Response\', \'description\': "Output of the Large Language '
#             'Model in response to the input messages. This defaults to a '
#             'string, but returns the specified dictionary if the '
#             '\'output_structure\' input is provided."}}, \'requirements\': '
#             "{'cpu': 256, 'gpu': True, 'memory': 512, 'timeout': 120}, "
#             "'load_balancer_url': "
#             "'http://prod-u-uncer-ZyMsgs3OcVhg-545812851.eu-west-2.elb.amazonaws.com', "
#             "'queue_url': "
#             "'https://sqs.eu-west-2.amazonaws.com/939027885851/prod-uncertainty-engine-prompt-ll-uncertaintyenginepromptllmnodeQue-JGV2oKodOpvu', "
#             "'cache_url': "
#             "'redis-13325.c338.eu-west-2-1.ec2.redns.redis-cloud.com', "
#             "'version_types_lib': '0.4.0', 'version_base_image': 2, "
#             "'version_node': 0}, 'SemanticObjectDetection': {'id': "
#             "'SemanticObjectDetection', 'label': 'Semantic Object Detection', "
#             "'category': 'Model', 'description': 'Detect objects in image', "
#             "'long_description': 'Detect objects in image with text prompts', "
#             "'image_name': "
#             "'uncertainty-engine-semantic-object-detection-node', 'cost': 10, "
#             "'inputs': {'image': {'type': 'str', 'label': 'Image Byte String', "
#             "'description': 'Byte string exported from a Pillow image', "
#             "'required': True, 'set_in_node': True, 'default': None}, "
#             "'detection_prompt': {'type': 'str', 'label': 'Text Prompt', "
#             "'description': 'Text prompt for the object being detected', "
#             "'required': True, 'set_in_node': True, 'default': None}, "
#             "'detection_n_max': {'type': 'int', 'label': 'Maximum detections', "
#             "'description': 'Maximum number of bounding boxes to fit', "
#             "'required': True, 'set_in_node': True, 'default': 400}, "
#             "'detection_iou': {'type': 'float', 'label': 'IoU', 'description': "
#             "'Filtering IoU threshold', 'required': True, 'set_in_node': True, "
#             "'default': 0.2}, 'detection_confidence': {'type': 'float', "
#             "'label': 'Confidence', 'description': 'Detection confidence "
#             "threshold', 'required': True, 'set_in_node': True, 'default': "
#             "1e-05}, 'crop_filter_ratio': {'type': 'float', 'label': 'Size "
#             "filtering', 'description': 'Filter ratio based on size. Valid "
#             "detections cannot be larger than the mode based on this ratio', "
#             "'required': True, 'set_in_node': True, 'default': 0.3}, "
#             "'crop_padding': {'type': 'int', 'label': 'Crop Padding', "
#             "'description': 'Isotropic padding added to each bounding box "
#             "before cropping', 'required': True, 'set_in_node': True, "
#             "'default': 10}}, 'outputs': {'cropped_images': {'type': "
#             "'S3Storage', 'label': 'images', 'description': 'Cropped images of "
#             "each detection'}, 'cropped_bboxes': {'type': 'S3Storage', "
#             "'label': 'bboxes', 'description': 'Bounding boxes of each "
#             "detection'}}, 'requirements': {'cpu': 256, 'gpu': False, "
#             "'memory': 512, 'timeout': 600}, 'load_balancer_url': "
#             "'http://prod-u-uncer-IbT6lVyOMQeG-1478587277.eu-west-2.elb.amazonaws.com', "
#             "'queue_url': "
#             "'https://sqs.eu-west-2.amazonaws.com/939027885851/prod-uncertainty-engine-semantic--uncertaintyenginesemanticobjectde-QXwyMsBZEpbT', "
#             "'cache_url': "
#             "'redis-13325.c338.eu-west-2-1.ec2.redns.redis-cloud.com', "
#             "'version_types_lib': '0.4.0', 'version_base_image': 2, "
#             "'version_node': 1}, 'SemanticObjectSegmentation': {'id': "
#             "'SemanticObjectSegmentation', 'label': 'Semantic Object "
#             "Segmentation', 'category': 'Model', 'description': 'Segment "
#             "objects in image', 'long_description': 'Segment objects in image "
#             "with text prompts', 'image_name': "
#             "'uncertainty-engine-semantic-object-segmentation-node', 'cost': "
#             "40, 'inputs': {'images': {'type': 'list', 'label': 'Image Byte "
#             "Strings', 'description': 'Byte strings exported from a list of "
#             "Pillow images', 'required': True, 'set_in_node': True, 'default': "
#             "None}, 'segment_prompts': {'type': 'list[str]', 'label': 'Text "
#             "Prompts', 'description': 'List of prompts.', 'required': True, "
#             "'set_in_node': True, 'default': None}, 'segment_threshold': "
#             "{'type': 'float', 'label': 'Segmentation Threshold', "
#             "'description': 'Relative threshold [0, 1] limit for segmentation "
#             "masks', 'required': True, 'set_in_node': True, 'default': 0.75}, "
#             "'refine_threshold': {'type': 'float', 'label': 'Refinement "
#             "Threshold', 'description': 'Relative threshold limit [0, 1] for "
#             "segmentation masks during refinement step', 'required': True, "
#             "'set_in_node': True, 'default': 0.78}, 'refine_central_prompt': "
#             "{'type': 'bool', 'label': 'Automatic Central Prompt', "
#             "'description': 'Whether or not to try to automatically segment "
#             "only the object in the centre of the image', 'required': True, "
#             "'set_in_node': True, 'default': False}, 'do_preprocess': {'type': "
#             "'bool', 'label': 'Do Preprocess', 'description': 'Whether to "
#             'preprocess images with edge enhancement and Kuwahara filtering '
#             "before segmentation', 'required': True, 'set_in_node': True, "
#             "'default': True}, 'do_refinement': {'type': 'bool', 'label': 'Do "
#             "Refinement', 'description': 'Whether to return coarse masks or "
#             'refined masks. Refined masks are higher resolution but takes '
#             "longer to compute', 'required': True, 'set_in_node': True, "
#             "'default': True}}, 'outputs': {'segmentations': {'type': "
#             "'S3Storage', 'label': 'Segmentations', 'description': 'List of 2D "
#             'binary arrays representing the segmentations in original image '
#             "size'}}, 'requirements': {'cpu': 256, 'gpu': False, 'memory': "
#             "512, 'timeout': 600}, 'load_balancer_url': "
#             "'http://prod-u-uncer-1qSTfqzDmOvQ-1905481528.eu-west-2.elb.amazonaws.com', "
#             "'queue_url': "
#             "'https://sqs.eu-west-2.amazonaws.com/939027885851/prod-uncertainty-engine-semantic--uncertaintyenginesemanticobjectse-Pc9VDw7tMtiP', "
#             "'cache_url': "
#             "'redis-13325.c338.eu-west-2-1.ec2.redns.redis-cloud.com', "
#             "'version_types_lib': '0.4.0', 'version_base_image': 2, "
#             "'version_node': 0}, 'Splitter': {'id': 'Splitter', 'label': "
#             "'Splitter', 'category': 'Utility', 'description': 'Extracts "
#             "components from a dictionary', 'long_description': 'Extracts "
#             "components from a dictionary based on supplied key word.', "
#             "'image_name': 'uncertainty-engine-splitter-node', 'cost': 1, "
#             "'inputs': {'inputs': {'type': 'dict[str, Any]', 'label': "
#             "'Inputs', 'description': 'Inputs to be split based on supplied "
#             "keywords', 'required': True, 'set_in_node': False, 'default': "
#             "None}, 'keys': {'type': 'list[str]', 'label': 'Keys', "
#             "'description': 'List of items to extract from the input "
#             "dictionary', 'required': True, 'set_in_node': True, 'default': "
#             "None}}, 'outputs': {'value1': {'type': 'Any', 'label': 'Value 1', "
#             "'description': 'First extracted value'}, 'value2': {'type': "
#             "'Any', 'label': 'Value 2', 'description': 'Second extracted "
#             "value'}, 'value3': {'type': 'Any', 'label': 'Value 3', "
#             "'description': 'Third extracted value'}}, 'requirements': {'cpu': "
#             "256, 'gpu': False, 'memory': 512, 'timeout': 15}, "
#             "'load_balancer_url': "
#             "'http://prod-u-uncer-Cp22muOiCL9n-1323127328.eu-west-2.elb.amazonaws.com', "
#             "'queue_url': "
#             "'https://sqs.eu-west-2.amazonaws.com/939027885851/prod-uncertainty-engine-python-sp-uncertaintyenginepythonsplitterno-KD3u5uKY5SJa', "
#             "'cache_url': "
#             "'redis-13325.c338.eu-west-2-1.ec2.redns.redis-cloud.com', "
#             "'version_types_lib': '0.4.0', 'version_base_image': 2, "
#             "'version_node': 0}, 'TrainModel': {'id': 'TrainModel', 'label': "
#             "'Train Model', 'category': 'MachineLearningModels', "
#             "'description': 'Train a machine-learning model', "
#             "'long_description': 'Trains a Gaussian Process model on the input "
#             "data.', 'image_name': 'uncertainty-engine-train-model-node', "
#             "'cost': 5, 'inputs': {'config': {'type': 'ModelConfig', 'label': "
#             "'Model Config', 'description': 'Configuration for the model', "
#             "'required': True, 'set_in_node': False, 'default': None}, "
#             "'inputs': {'type': 'CSVDataset', 'label': 'Input Dataset', "
#             "'description': 'Input dataset for training the model', "
#             "'required': True, 'set_in_node': True, 'default': None}, "
#             "'outputs': {'type': 'CSVDataset', 'label': 'Output Dataset', "
#             "'description': 'Output dataset for training the model', "
#             "'required': True, 'set_in_node': True, 'default': None}}, "
#             "'outputs': {'model': {'type': 'MachineLearningModel', 'label': "
#             "'Machine Learning Model', 'description': 'A trained "
#             "machine-learning model'}}, 'requirements': {'cpu': 8192, 'gpu': "
#             "False, 'memory': 16384, 'timeout': 1200}, 'load_balancer_url': "
#             "'http://prod-u-uncer-ye4H6IfCKcQU-2050507358.eu-west-2.elb.amazonaws.com', "
#             "'queue_url': "
#             "'https://sqs.eu-west-2.amazonaws.com/939027885851/prod-uncertainty-engine-train-mod-uncertaintyenginetrainmodelnodeQu-1D0RGFSj23ve', "
#             "'cache_url': "
#             "'redis-13325.c338.eu-west-2-1.ec2.redns.redis-cloud.com', "
#             "'version_types_lib': '0.4.0', 'version_base_image': 2, "
#             "'version_node': 1}, 'LLMConfig': {'id': 'LLMConfig', 'label': "
#             "'LLM Config', 'category': 'Agentic', 'description': 'LLM "
#             "configuration', 'long_description': 'Specify the configuration "
#             "for your LLM asset to use in your workflow.', 'image_name': "
#             "'uncertainty-engine-l-l-m-config-node', 'cost': 0, 'inputs': "
#             '{\'provider\': {\'type\': \'Literal["openai", "ollama"]\', '
#             "'label': 'Provider', 'description': 'Model provider for the "
#             "LLM.', 'required': True, 'set_in_node': True, 'default': None}, "
#             "'model': {'type': 'str', 'label': 'Model', 'description': 'Model "
#             "selection from provider.', 'required': True, 'set_in_node': True, "
#             "'default': None}, 'temperature': {'type': 'float', 'label': "
#             "'Temperature', 'description': 'The degree to which the model is "
#             'allowed to be creative; 0 indicates the model is deterministic '
#             "where as 1 indicates high variance.', 'required': False, "
#             "'set_in_node': True, 'default': 0.0}, 'ollama_url': {'type': "
#             "'str', 'label': 'Ollama URL', 'description': 'URL at which the "
#             "Ollama model is deployed.', 'required': False, 'set_in_node': "
#             "True, 'default': None}, 'openai_api_key': {'type': 'str', "
#             "'label': 'OpenAI API Key', 'description': 'API key for OpenAI.', "
#             "'required': False, 'set_in_node': True, 'default': None}}, "
#             "'outputs': {'config': {'type': 'LLMConfig', 'label': 'LLM "
#             "Config', 'description': 'Configuration for the LLM asset.'}}, "
#             "'requirements': {'cpu': 256, 'gpu': False, 'memory': 512, "
#             "'timeout': 15}, 'load_balancer_url': "
#             "'http://prod-u-uncer-0woiXnfqGQeI-723374600.eu-west-2.elb.amazonaws.com', "
#             "'queue_url': "
#             "'https://sqs.eu-west-2.amazonaws.com/939027885851/prod-uncertainty-engine-llm-confi-uncertaintyenginellmconfignodeQue-6qEEj53LUluo', "
#             "'cache_url': "
#             "'redis-13325.c338.eu-west-2-1.ec2.redns.redis-cloud.com', "
#             "'version_types_lib': '0.4.0', 'version_base_image': 2, "
#             "'version_node': 0}, 'GetContext': {'id': 'GetContext', 'label': "
#             "'Get Context', 'category': 'Agentic', 'description': 'Get context "
#             'from documents\', \'long_description\': "Use vector store '
#             "retrieval to find the most relevant documents to a user's "
#             'query.", \'image_name\': \'uncertainty-engine-get-context-node\', '
#             "'cost': 10, 'inputs': {'search_query': {'type': 'str', 'label': "
#             "'Search Query', 'description': 'Search query to find the most "
#             "relevant documents.', 'required': True, 'set_in_node': False, "
#             "'default': None}, 'text_embeddings_config': {'type': "
#             "'TextEmbeddingsConfig', 'label': 'Embedding Model', "
#             "'description': 'Embedding model to use for retrieval.', "
#             "'required': True, 'set_in_node': False, 'default': None}, "
#             "'documents': {'type': 'Optional[list[S3Storage]]', 'label': "
#             "'Documents', 'description': 'List of documents to search "
#             "through.', 'required': False, 'set_in_node': False, 'default': "
#             "None}, 'vectorstore': {'type': 'Optional[VectorStoreConfig]', "
#             "'label': 'Vectorstore', 'description': 'Vectorstore of documents "
#             "to use for retrieval.', 'required': False, 'set_in_node': False, "
#             "'default': None}, 'num_docs': {'type': 'int', 'label': 'Number of "
#             "documents to retrieve', 'description': 'Number of documents to "
#             "retrieve based on highest relevance.', 'required': False, "
#             "'set_in_node': True, 'default': 7}}, 'outputs': {'excerpts': "
#             "{'type': 'list[str]', 'label': 'Excerpts', 'description': 'A list "
#             "of excerpts relevant to the search query.'}, 'references': "
#             "{'type': 'list[S3Storage]', 'label': 'References', 'description': "
#             "'A list of references to the documents from which the excerpts "
#             "were taken.'}}, 'requirements': {'cpu': 256, 'gpu': False, "
#             "'memory': 512, 'timeout': 120}, 'load_balancer_url': "
#             "'http://prod-u-uncer-y54YPyQI4nKh-1636712960.eu-west-2.elb.amazonaws.com', "
#             "'queue_url': "
#             "'https://sqs.eu-west-2.amazonaws.com/939027885851/prod-uncertainty-engine-get-conte-uncertaintyenginegetcontextnodeQu-QoZDGV1CLwLW', "
#             "'cache_url': "
#             "'redis-13325.c338.eu-west-2-1.ec2.redns.redis-cloud.com', "
#             "'version_types_lib': '0.4.0', 'version_base_image': 2, "
#             "'version_node': 0}, 'AnalyseVariance': {'id': 'AnalyseVariance', "
#             "'label': 'Analyse Variance', 'category': 'Datasets', "
#             "'description': 'Analyse variance explained by decomposed "
#             "dimensions', 'long_description': 'Analyse how much information is "
#             'captured by each transformed dimension after decomposing your '
#             "dataset.', 'image_name': "
#             "'uncertainty-engine-analyse-variance-node', 'cost': 2, 'inputs': "
#             "{'dataset': {'type': 'CSVDataset', 'label': 'Dataset', "
#             "'description': 'Dataset to analyse', 'required': True, "
#             "'set_in_node': False, 'default': None}, 'columns': {'type': "
#             "'Optional[list[str]]', 'label': 'Columns', 'description': "
#             "'Selected columns to analyse. If none are selected, all columns "
#             "will be used.', 'required': False, 'set_in_node': True, "
#             "'default': None}}, 'outputs': {'variance_analysis': {'type': "
#             "'CSVDataset', 'label': 'Variance Analysis', 'description': "
#             "'Results dataset from the variance analysis'}}, 'requirements': "
#             "{'cpu': 4096, 'gpu': False, 'memory': 10240, 'timeout': 1200}, "
#             "'load_balancer_url': "
#             "'http://prod-u-uncer-sAEL03Ot5RYj-335044317.eu-west-2.elb.amazonaws.com', "
#             "'queue_url': "
#             "'https://sqs.eu-west-2.amazonaws.com/939027885851/prod-uncertainty-engine-analyse-v-uncertaintyengineanalysevariancen-I6S47of2tELa', "
#             "'cache_url': "
#             "'redis-13325.c338.eu-west-2-1.ec2.redns.redis-cloud.com', "
#             "'version_types_lib': '0.4.0', 'version_base_image': 2, "
#             "'version_node': 0}, 'BuildSensorDesigner': {'id': "
#             "'BuildSensorDesigner', 'label': 'Build Sensor Designer', "
#             "'category': 'SensorDesign', 'description': 'Build a sensor "
#             "designer', 'long_description': 'Build a sensor designer', "
#             "'image_name': 'uncertainty-engine-build-sensor-designer-node', "
#             "'cost': 1, 'inputs': {'sensor_data': {'type': 'CSVDataset', "
#             "'label': 'Sensor Dataset', 'description': 'Data from the "
#             "simulated sensors.', 'required': True, 'set_in_node': True, "
#             "'default': None}, 'quantities_of_interest_data': {'type': "
#             "'Optional[CSVDataset]', 'label': 'Quantities of Interest "
#             'Dataset\', \'description\': "Data from quantites that don\'t '
#             'directly come from sensor readings.", \'required\': False, '
#             "'set_in_node': True, 'default': None}, 'sigma': {'type': "
#             "'Optional[Union[float, list[float]]]', 'label': 'Sensor "
#             "Uncertainty', 'description': 'The standard deviation of the "
#             "sensor noise.', 'required': False, 'set_in_node': True, "
#             "'default': None}}, 'outputs': {'sensor_designer': {'type': "
#             "'SensorDesigner', 'label': 'Sensor Designer', 'description': 'A "
#             'Sensor Designer that can be used to generate or score sensor '
#             "readings.'}}, 'requirements': {'cpu': 2048, 'gpu': False, "
#             "'memory': 4096, 'timeout': 3600}, 'load_balancer_url': "
#             "'http://prod-u-uncer-6BHzmLGjcnX5-595965229.eu-west-2.elb.amazonaws.com', "
#             "'queue_url': "
#             "'https://sqs.eu-west-2.amazonaws.com/939027885851/prod-uncertainty-engine-build-sen-uncertaintyenginebuildsensordesig-nOYjxJ1WflDG', "
#             "'cache_url': "
#             "'redis-13325.c338.eu-west-2-1.ec2.redns.redis-cloud.com', "
#             "'version_types_lib': '0.4.0', 'version_base_image': 2, "
#             "'version_node': 0}, 'Workflow': {'id': 'Workflow', 'label': "
#             "'Workflow', 'category': 'Workflow', 'description': 'An network of "
#             "nodes', 'long_description': 'Run a collection of nodes in a "
#             "directed graph', 'image_name': "
#             "'uncertainty-engine-workflow-node', 'cost': 0, 'inputs': "
#             "{'external_input_id': {'type': 'str', 'label': 'External Input "
#             "ID', 'description': 'The ID of the external input to the "
#             'workflow. (Used by a graph to determine the external input to the '
#             "workflow.)', 'required': True, 'set_in_node': True, 'default': "
#             "None}, 'inputs': {'type': 'dict[str, Any]', 'label': 'Inputs', "
#             "'description': 'Workflow input and configuration data.', "
#             "'required': True, 'set_in_node': True, 'default': None}, 'graph': "
#             "{'type': 'Graph', 'label': 'Graph', 'description': 'The graph of "
#             "nodes to run.', 'required': True, 'set_in_node': True, 'default': "
#             "None}, 'requested_output': {'type': 'dict[str, Handle]', 'label': "
#             "'Requested Output', 'description': 'The requested output data.', "
#             "'required': True, 'set_in_node': True, 'default': None}}, "
#             "'outputs': {'outputs': {'type': 'dict[str, Any]', 'label': "
#             "'Output', 'description': 'The requested output data collected "
#             "from the nodes in the graph.'}}, 'requirements': {'cpu': 256, "
#             "'gpu': False, 'memory': 512, 'timeout': 7200}, "
#             "'load_balancer_url': "
#             "'http://prod-u-uncer-LezWCMRwK2pr-1881009082.eu-west-2.elb.amazonaws.com', "
#             "'queue_url': "
#             "'https://sqs.eu-west-2.amazonaws.com/939027885851/prod-uncertainty-engine-workflow--uncertaintyengineworkflownodeQueu-93XPU42sXde9', "
#             "'cache_url': "
#             "'redis-13325.c338.eu-west-2-1.ec2.redns.redis-cloud.com', "
#             "'version_types_lib': '0.4.0', 'version_base_image': 2, "
#             "'version_node': 4}, 'Dict': {'id': 'Dict', 'label': 'Dictionary', "
#             "'category': 'Input', 'description': 'A dictionary of mappings', "
#             "'long_description': 'A map between strings and things.', "
#             "'image_name': 'uncertainty-engine-dict-node', 'cost': 1, "
#             "'inputs': {'value': {'type': 'dict', 'label': 'Dictionary', "
#             "'description': 'Dictionary of mappings', 'required': True, "
#             "'set_in_node': True, 'default': None}}, 'outputs': {'value': "
#             "{'type': 'dict', 'label': 'Dictionary', 'description': "
#             "'Dictionary of mappings'}}, 'requirements': {'cpu': 256, 'gpu': "
#             "False, 'memory': 512, 'timeout': 15}, 'load_balancer_url': "
#             "'http://prod-u-uncer-ZszhanegOal1-1771348083.eu-west-2.elb.amazonaws.com', "
#             "'queue_url': "
#             "'https://sqs.eu-west-2.amazonaws.com/939027885851/prod-uncertainty-engine-dict-node-uncertaintyenginedictnodeQueueC50-VJuEAO1EjKnG', "
#             "'cache_url': "
#             "'redis-13325.c338.eu-west-2-1.ec2.redns.redis-cloud.com', "
#             "'version_types_lib': '0.4.0', 'version_base_image': 2, "
#             "'version_node': 1}, 'CreateDatasetSlice': {'id': "
#             "'CreateDatasetSlice', 'label': 'Create Dataset Slice', "
#             "'category': 'Datasets', 'description': 'Create a slice through a "
#             "parameter space', 'long_description': 'Create a slice through a "
#             "parameter space', 'image_name': "
#             "'uncertainty-engine-create-dataset-slice-node', 'cost': 1, "
#             "'inputs': {'variable': {'type': 'str', 'label': 'Variable', "
#             "'description': 'Variable to slice', 'required': True, "
#             "'set_in_node': True, 'default': None}, 'min': {'type': 'float', "
#             "'label': 'Minimum', 'description': 'Minimum value for slice', "
#             "'required': True, 'set_in_node': True, 'default': None}, 'max': "
#             "{'type': 'float', 'label': 'Maximum', 'description': 'Maximum "
#             "value for slice', 'required': True, 'set_in_node': True, "
#             "'default': None}, 'fixed_values': {'type': 'dict[str, float]', "
#             "'label': 'Fixed values', 'description': 'Values to hold fixed "
#             "while slicing', 'required': False, 'set_in_node': True, "
#             "'default': {}}, 'num_points': {'type': 'int', 'label': 'Number of "
#             "points', 'description': 'Number of points in slice', 'required': "
#             "False, 'set_in_node': True, 'default': 101}}, 'outputs': {'data': "
#             "{'type': 'CSVDataset', 'label': 'Dataset', 'description': 'Slice "
#             "dataset'}}, 'requirements': {'cpu': 256, 'gpu': False, 'memory': "
#             "512, 'timeout': 15}, 'load_balancer_url': "
#             "'http://prod-u-uncer-Yd9F5myux3a8-995478390.eu-west-2.elb.amazonaws.com', "
#             "'queue_url': "
#             "'https://sqs.eu-west-2.amazonaws.com/939027885851/prod-uncertainty-engine-create-da-uncertaintyenginecreatedatasetsli-T50ialdOW4vQ', "
#             "'cache_url': "
#             "'redis-13325.c338.eu-west-2-1.ec2.redns.redis-cloud.com', "
#             "'version_types_lib': '0.4.0', 'version_base_image': 2, "
#             "'version_node': 0}, 'Recommend': {'id': 'Recommend', 'label': "
#             "'Recommend', 'category': 'MachineLearningModels', 'description': "
#             "'Draw recommended data points from a trained model', "
#             "'long_description': 'Draw recommended data points from a trained "
#             "model', 'image_name': 'uncertainty-engine-recommend-node', "
#             "'cost': 1, 'inputs': {'model': {'type': 'MachineLearningModel', "
#             "'label': 'Model', 'description': 'Machine-learning model', "
#             "'required': True, 'set_in_node': False, 'default': None}, "
#             "'number_of_points': {'type': 'int', 'label': 'Number of points', "
#             "'description': 'The number of points to recommend.', 'required': "
#             "True, 'set_in_node': True, 'default': None}, "
#             "'acquisition_function': {'type': "
#             '\'Literal["ExpectedImprovement", "LogExpectedImprovement", '
#             '"PosteriorMean", "PosteriorStandardDeviation", '
#             '"MonteCarloExpectedImprovement", '
#             '"MonteCarloLogExpectedImprovement", '
#             '"MonteCarloNegativeIntegratedPosteriorVariance"]\', \'label\': '
#             "'Acquisition function', 'description': 'The acquisition function "
#             "to use for recommending points.', 'required': True, "
#             "'set_in_node': True, 'default': None}}, 'outputs': "
#             "{'recommended_points': {'type': 'CSVDataset', 'label': "
#             "'Recommended points', 'description': 'A dataset containing the "
#             "recommended points from the model'}, "
#             "'acquisition_function_value': {'type': 'float', 'label': "
#             "'Acquisition function value', 'description': 'Acquisition "
#             "function value for the recommended points'}}, 'requirements': "
#             "{'cpu': 8192, 'gpu': False, 'memory': 16384, 'timeout': 1200}, "
#             "'load_balancer_url': "
#             "'http://prod-u-uncer-aYil3v1t3LK9-150902226.eu-west-2.elb.amazonaws.com', "
#             "'queue_url': "
#             "'https://sqs.eu-west-2.amazonaws.com/939027885851/prod-uncertainty-engine-recommend-uncertaintyenginerecommendnodeQue-nMjfRgSwsQTM', "
#             "'cache_url': "
#             "'redis-13325.c338.eu-west-2-1.ec2.redns.redis-cloud.com', "
#             "'version_types_lib': '0.4.0', 'version_base_image': 2, "
#             "'version_node': 0}, 'Download': {'id': 'Download', 'label': "
#             "'Download', 'category': 'Output', 'description': 'Download a "
#             "file', 'long_description': 'Download a file', 'image_name': "
#             "'uncertainty-engine-download-node', 'cost': 1, 'inputs': {'file': "
#             "{'type': 'Union[CSVDataset, ChatHistory, MachineLearningModel, "
#             "SensorDesigner, VTU]', 'label': 'File', 'description': 'File to "
#             "download', 'required': True, 'set_in_node': False, 'default': "
#             "None}}, 'outputs': {'file': {'type': 'str', 'label': 'Download', "
#             "'description': 'File to download'}}, 'requirements': {'cpu': "
#             "1024, 'gpu': False, 'memory': 2048, 'timeout': 180}, "
#             "'load_balancer_url': "
#             "'http://prod-u-uncer-u2eIWQ8vYxLp-256655555.eu-west-2.elb.amazonaws.com', "
#             "'queue_url': "
#             "'https://sqs.eu-west-2.amazonaws.com/939027885851/prod-uncertainty-engine-download--uncertaintyenginedownloadnodeQueu-BMm2pGUHDWQG', "
#             "'cache_url': "
#             "'redis-13325.c338.eu-west-2-1.ec2.redns.redis-cloud.com', "
#             "'version_types_lib': '0.4.0', 'version_base_image': 2, "
#             "'version_node': 0}, 'FilterDataset': {'id': 'FilterDataset', "
#             "'label': 'Filter Dataset', 'category': 'Datasets', 'description': "
#             "'Filter a dataset by column names', 'long_description': 'Filter a "
#             "dataset by using a list of column names', 'image_name': "
#             "'uncertainty-engine-filter-dataset-node', 'cost': 1, 'inputs': "
#             "{'dataset': {'type': 'CSVDataset', 'label': 'Dataset', "
#             "'description': 'The dataset to filter', 'required': True, "
#             "'set_in_node': False, 'default': None}, 'columns': {'type': "
#             "'list[str]', 'label': 'Columns', 'description': 'The list of "
#             "columns to keep', 'required': True, 'set_in_node': True, "
#             "'default': None}}, 'outputs': {'dataset': {'type': 'CSVDataset', "
#             "'label': 'Dataset', 'description': 'The filtered dataset'}}, "
#             "'requirements': {'cpu': 256, 'gpu': False, 'memory': 512, "
#             "'timeout': 15}, 'load_balancer_url': "
#             "'http://prod-u-uncer-uiEEEKArkpdb-1134658750.eu-west-2.elb.amazonaws.com', "
#             "'queue_url': "
#             "'https://sqs.eu-west-2.amazonaws.com/939027885851/prod-uncertainty-engine-filter-da-uncertaintyenginefilterdatasetnod-JP4Gim4gGoRh', "
#             "'cache_url': "
#             "'redis-13325.c338.eu-west-2-1.ec2.redns.redis-cloud.com', "
#             "'version_types_lib': '0.4.0', 'version_base_image': 2, "
#             "'version_node': 0}, 'ExportTorchScript': {'id': "
#             "'ExportTorchScript', 'label': 'Export To TorchScript', "
#             "'category': 'MachineLearningModels', 'description': 'Export to a "
#             "TorchScript file', 'long_description': 'Export to a TorchScript "
#             "file so you can download your optimised model.', 'image_name': "
#             "'uncertainty-engine-export-torch-script-node', 'cost': 4, "
#             "'inputs': {'model': {'type': 'MachineLearningModel', 'label': "
#             "'Model', 'description': 'Model you want to export to "
#             "TorchScript', 'required': True, 'set_in_node': False, 'default': "
#             "None}, 'validation_inputs': {'type': 'CSVDataset', 'label': "
#             '\'Validation Input Data\', \'description\': "Sample input data to '
#             'validate the exported model\'s predictions", \'required\': True, '
#             "'set_in_node': False, 'default': None}, 'observation_noise': "
#             "{'type': 'Optional[bool]', 'label': 'Observation Noise', "
#             "'description': 'Whether to include observation noise', "
#             "'required': False, 'set_in_node': True, 'default': True}}, "
#             "'outputs': {'torch_script': {'type': 'TorchScript', 'label': "
#             "'TorchScript File', 'description': 'The exported TorchScript "
#             "file'}}, 'requirements': {'cpu': 256, 'gpu': False, 'memory': "
#             "512, 'timeout': 120}, 'load_balancer_url': "
#             "'http://prod-u-uncer-8pZBVS6diVw8-1857308704.eu-west-2.elb.amazonaws.com', "
#             "'queue_url': "
#             "'https://sqs.eu-west-2.amazonaws.com/939027885851/prod-uncertainty-engine-export-to-uncertaintyengineexporttorchscrip-1btMjWzvGtl3', "
#             "'cache_url': "
#             "'redis-13325.c338.eu-west-2-1.ec2.redns.redis-cloud.com', "
#             "'version_types_lib': '0.4.0', 'version_base_image': 2, "
#             "'version_node': 0}, 'PcdProcessing': {'id': 'PcdProcessing', "
#             "'label': 'KWP4 Pcd Processing', 'category': 'Algorithm', "
#             "'description': 'Point Cloud Processing for KWP4', "
#             "'long_description': 'Point Cloud Processing for KWP4', "
#             "'image_name': 'uncertainty-engine-k-w-p4-pcd-processing-node', "
#             "'cost': 1, 'inputs': {'pcd_data': {'type': 'S3Storage', 'label': "
#             "'Point Cloud', 'description': 'A point cloud encoded as string', "
#             "'required': True, 'set_in_node': True, 'default': None}, "
#             "'line_detection': {'type': 'bool', 'label': 'Line Detection', "
#             "'description': 'Flag to detect lines in the point cloud', "
#             "'required': True, 'set_in_node': True, 'default': False}, "
#             "'colour_clustering': {'type': 'bool', 'label': 'Colour "
#             "Clustering', 'description': 'Flag to cluster points based on "
#             "colour', 'required': True, 'set_in_node': True, 'default': "
#             "False}}, 'outputs': {'summary_df': {'type': 'S3Storage', 'label': "
#             "'Summary DataFrame', 'description': 'Summary statistics of "
#             "measurements'}}, 'requirements': {'cpu': 256, 'gpu': False, "
#             "'memory': 512, 'timeout': 600}, 'load_balancer_url': "
#             "'http://prod-u-uncer-09jjOL7JcpIg-774880768.eu-west-2.elb.amazonaws.com', "
#             "'queue_url': "
#             "'https://sqs.eu-west-2.amazonaws.com/939027885851/prod-uncertainty-engine-k-w-p4-pc-uncertaintyenginekwp4pcdprocessin-aaF5BSLTcEGV', "
#             "'cache_url': "
#             "'redis-13325.c338.eu-west-2-1.ec2.redns.redis-cloud.com', "
#             "'version_types_lib': '0.4.0', 'version_base_image': 2, "
#             "'version_node': 0}, 'ModelConfig': {'id': 'ModelConfig', 'label': "
#             "'Model Config', 'category': 'MachineLearningModels', "
#             "'description': 'Config for a machine learning model', "
#             "'long_description': 'Config for a machine learning model', "
#             "'image_name': 'uncertainty-engine-model-config-node', 'cost': 1, "
#             "'inputs': {'input_variance': {'type': 'float', 'label': 'Input "
#             "Variance', 'description': 'Percentage of variance to retain in "
#             "the input data', 'required': False, 'set_in_node': True, "
#             "'default': None}, 'input_retained_dimensions': {'type': 'int', "
#             "'label': 'Input Retained Dimensions', 'description': 'Number of "
#             "dimensions to retain in the input data', 'required': False, "
#             "'set_in_node': True, 'default': None}, 'output_variance': "
#             "{'type': 'float', 'label': 'Output Variance', 'description': "
#             "'Percentage of variance to retain in the output data', "
#             "'required': False, 'set_in_node': True, 'default': None}, "
#             "'output_retained_dimensions': {'type': 'int', 'label': 'Output "
#             "Retained Dimensions', 'description': 'Number of dimensions to "
#             "retain in the output data', 'required': False, 'set_in_node': "
#             "True, 'default': None}, 'model_type': {'type': "
#             '\'Literal["BernoulliClassificationGPTorch", "SingleTaskGPTorch", '
#             '"SingleTaskVariationalGPTorch"]\', \'label\': \'Model Type\', '
#             "'description': 'Type of model to use', 'required': False, "
#             "'set_in_node': True, 'default': 'SingleTaskGPTorch'}, 'kernel': "
#             "{'type': 'Optional[str]', 'label': 'Kernel', 'description': 'Type "
#             "of kernel to use for the model', 'required': False, "
#             "'set_in_node': True, 'default': None}, 'warp_inputs': {'type': "
#             "'bool', 'label': 'Warp Inputs', 'description': 'Whether to warp "
#             "the inputs for the model', 'required': False, 'set_in_node': "
#             "True, 'default': False}, 'seed': {'type': 'Optional[int]', "
#             "'label': 'Seed', 'description': 'Seed for  reproducible "
#             "training', 'required': False, 'set_in_node': True, 'default': "
#             "None}}, 'outputs': {'config': {'type': 'ModelConfig', 'label': "
#             "'Model Config', 'description': 'A model config object'}}, "
# ...
#             "'label': 'Number', 'description': 'Real number'}}, "
#             "'requirements': {'cpu': 256, 'gpu': False, 'memory': 512, "
#             "'timeout': 15}, 'load_balancer_url': "
#             "'http://prod-u-uncer-PL6BtGnEmjCb-2091997012.eu-west-2.elb.amazonaws.com', "
#             "'queue_url': "
#             "'https://sqs.eu-west-2.amazonaws.com/939027885851/prod-uncertainty-engine-number-no-uncertaintyenginenumbernodeQueueD-LpA1q7SGQDZ5', "
#             "'cache_url': "
#             "'redis-13325.c338.eu-west-2-1.ec2.redns.redis-cloud.com', "
#             "'version_types_lib': '0.4.0', 'version_base_image': 2, "
#             "'version_node': 2}, 'Save': {'id': 'Save', 'label': 'Save', "
#             "'category': 'Output', 'description': 'Save data', "
#             "'long_description': 'Save data to your project cloud storage.', "
#             "'image_name': 'uncertainty-engine-save-node', 'cost': 1, "
#             "'inputs': {'account_id': {'type': 'str', 'label': 'Account ID', "
#             "'description': 'Account ID', 'required': True, 'set_in_node': "
#             "True, 'default': None}, 'data': {'type': 'Union[ChatHistory, "
#             "CSVDataset, MachineLearningModel]', 'label': 'Data', "
#             "'description': 'Data to store', 'required': True, 'set_in_node': "
#             "False, 'default': None}, 'file_id': {'type': 'str', 'label': "
#             "'File ID', 'description': 'File ID', 'required': True, "
#             "'set_in_node': True, 'default': None}, 'project_id': {'type': "
#             "'str', 'label': 'Project ID', 'description': 'Project ID', "
#             "'required': True, 'set_in_node': True, 'default': None}}, "
#             "'outputs': {}, 'requirements': {'cpu': 1024, 'gpu': False, "
#             "'memory': 4096, 'timeout': 600}, 'load_balancer_url': "
#             "'http://prod-u-uncer-c32ku8eWuV2B-1816169507.eu-west-2.elb.amazonaws.com', "
#             "'queue_url': "
#             "'https://sqs.eu-west-2.amazonaws.com/939027885851/prod-uncertainty-engine-save-node-uncertaintyenginesavenodeQueueB51-rG2IJx0vagE6', "
#             "'cache_url': "
#             "'redis-13325.c338.eu-west-2-1.ec2.redns.redis-cloud.com', "
#             "'version_types_lib': '0.4.0', 'version_base_image': 2, "
#             "'version_node': 0}, 'Message': {'id': 'Message', 'label': 'Create "
#             "Message', 'category': 'Agentic', 'description': 'Write a "
#             "message', 'long_description': 'Write a message to use in your LLM "
#             "workfow', 'image_name': 'uncertainty-engine-message-node', "
#             "'cost': 1, 'inputs': {'content': {'type': 'Any', 'label': "
#             "'Content', 'description': 'Message content', 'required': True, "
#             "'set_in_node': True, 'default': None}, 'role': {'type': "
#             '\'Literal["instruction", "user", "engine"]\', \'label\': '
#             "'Role', 'description': 'Message role', 'required': True, "
#             "'set_in_node': True, 'default': 'user'}}, 'outputs': {'message': "
#             "{'type': 'Message', 'label': 'Message', 'description': 'New "
#             "message'}}, 'requirements': {'cpu': 256, 'gpu': False, 'memory': "
#             "512, 'timeout': 15}, 'load_balancer_url': "
#             "'http://prod-u-uncer-koaj8uel4Rgi-1560275153.eu-west-2.elb.amazonaws.com', "
#             "'queue_url': "
#             "'https://sqs.eu-west-2.amazonaws.com/939027885851/prod-uncertainty-engine-message-n-uncertaintyenginemessagenodeQueue-6qAt9ELJ07Kr', "
#             "'cache_url': "
#             "'redis-13325.c338.eu-west-2-1.ec2.redns.redis-cloud.com', "
#             "'version_types_lib': '0.4.0', 'version_base_image': 2, "
#             "'version_node': 0}, 'PredictModel': {'id': 'PredictModel', "
#             "'label': 'Predict Model', 'category': 'MachineLearningModels', "
#             "'description': 'Make predictions using a machine-learning model', "
#             "'long_description': 'Generate predictions using a trained "
#             "machine-learning model.', 'image_name': "
#             "'uncertainty-engine-predict-model-node', 'cost': 5, 'inputs': "
#             "{'model': {'type': 'MachineLearningModel', 'label': 'Model', "
#             "'description': 'Machine-learning model', 'required': True, "
#             "'set_in_node': False, 'default': None}, 'dataset': {'type': "
#             "'CSVDataset', 'label': 'Dataset', 'description': 'Dataset for "
#             "predictions', 'required': True, 'set_in_node': False, 'default': "
#             "None}}, 'outputs': {'prediction': {'type': 'CSVDataset', 'label': "
#             "'Predictions', 'description': 'Predicted output values from the "
#             "model'}, 'uncertainty': {'type': 'CSVDataset', 'label': "
#             "'Uncertainty', 'description': 'Predicted uncertainty values from "
#             "the model'}}, 'requirements': {'cpu': 4096, 'gpu': False, "
#             "'memory': 16384, 'timeout': 600}, 'load_balancer_url': "
#             "'http://prod-u-uncer-dSMYuuLoczTd-1088419223.eu-west-2.elb.amazonaws.com', "
#             "'queue_url': "
#             "'https://sqs.eu-west-2.amazonaws.com/939027885851/prod-uncertainty-engine-predict-m-uncertaintyenginepredictmodelnode-puV6iivBr0Na', "
#             "'cache_url': "
#             "'redis-13325.c338.eu-west-2-1.ec2.redns.redis-cloud.com', "
#             "'version_types_lib': '0.4.0', 'version_base_image': 2, "
#             "'version_node': 1}, 'EmbeddingsConfig': {'id': "
#             "'EmbeddingsConfig', 'label': 'Embeddings Config', 'category': "
#             "'Agentic', 'description': 'Connection configuration for text "
#             "embedding models.', 'long_description': 'Connection configuration "
#             "for text embedding models.', 'image_name': "
#             "'uncertainty-engine-embeddings-config-node', 'cost': 1, 'inputs': "
#             '{\'provider\': {\'type\': \'Literal["openai","ollama"]\', '
#             "'label': 'Provider', 'description': 'Embeddings model provider', "
#             "'required': True, 'set_in_node': True, 'default': None}, 'model': "
#             "{'type': 'Optional[str]', 'label': 'Model', 'description': "
#             "'Embeddings model name', 'required': False, 'set_in_node': True, "
#             "'default': None}, 'ollama_url': {'type': 'Optional[str]', "
#             "'label': 'Ollama URL', 'description': 'URL of the Ollama server', "
#             "'required': False, 'set_in_node': True, 'default': None}, "
#             "'openai_api_key': {'type': 'Optional[str]', 'label': 'OpenAI API "
#             "Key', 'description': 'API key for OpenAI model', 'required': "
#             "False, 'set_in_node': True, 'default': None}}, 'outputs': "
#             "{'embeddings_config': {'type': 'TextEmbeddingsConfig', 'label': "
#             "'Embeddings Config', 'description': 'Embeddings configuration'}}, "
#             "'requirements': {'cpu': 256, 'gpu': False, 'memory': 512, "
#             "'timeout': 15}, 'load_balancer_url': "
#             "'http://prod-u-uncer-x5jKK7yrSPXu-1319820895.eu-west-2.elb.amazonaws.com', "
#             "'queue_url': "
#             "'https://sqs.eu-west-2.amazonaws.com/939027885851/prod-uncertainty-engine-embedding-uncertaintyengineembeddingsconfig-r8f6yg7nG66T', "
#             "'cache_url': "
#             "'redis-13325.c338.eu-west-2-1.ec2.redns.redis-cloud.com', "
#             "'version_types_lib': '0.4.0', 'version_base_image': 2, "
#             "'version_node': 0}, 'CreateInitialDesign': {'id': "
#             "'CreateInitialDesign', 'label': 'Create Initial Design', "
#             "'category': 'Datasets', 'description': 'Generate a set of samples "
#             "in a defined parameter space', 'long_description': 'Generate a "
#             "set of samples in a defined parameter space', 'image_name': "
#             "'uncertainty-engine-create-initial-design-node', 'cost': 1, "
#             "'inputs': {'labels': {'type': 'list[str]', 'label': 'Labels', "
#             "'description': 'Labels for dimensions of the defined parameter "
#             "space', 'required': True, 'set_in_node': True, 'default': None}, "
#             "'lower_bounds': {'type': 'list[float]', 'label': 'Lower bounds', "
#             "'description': 'The lower bound for each parameter', 'required': "
#             "True, 'set_in_node': True, 'default': None}, 'upper_bounds': "
#             "{'type': 'list[float]', 'label': 'Maximum', 'description': 'The "
#             "upper bound for each parameter', 'required': True, 'set_in_node': "
#             "True, 'default': None}, 'num_points': {'type': 'int', 'label': "
#             "'Number of points', 'description': 'The number of points to "
#             "generate', 'required': True, 'set_in_node': True, 'default': "
#             "None}, 'seed': {'type': 'int', 'label': 'Seed', 'description': "
#             "'The random seed to use for generating the samples', 'required': "
#             "False, 'set_in_node': True, 'default': None}}, 'outputs': "
#             "{'samples': {'type': 'CSVDataset', 'label': 'Samples', "
#             "'description': 'The generated design samples'}}, 'requirements': "
#             "{'cpu': 256, 'gpu': False, 'memory': 512, 'timeout': 60}, "
#             "'load_balancer_url': "
#             "'http://prod-u-uncer-ZA9JTfhxXWai-1533349187.eu-west-2.elb.amazonaws.com', "
#             "'queue_url': "
#             "'https://sqs.eu-west-2.amazonaws.com/939027885851/prod-uncertainty-engine-create-in-uncertaintyenginecreateinitialdes-dwEHHckrL6R8', "
#             "'cache_url': "
#             "'redis-13325.c338.eu-west-2-1.ec2.redns.redis-cloud.com', "
#             "'version_types_lib': '0.4.0', 'version_base_image': 2, "
#             "'version_node': 0}}}\n"
#             'Waited 4e-06/7200 seconds for LoadDataset…\n'
#             'Waited 0.516661/7200 seconds for LoadDataset…\n'
#             'Waited 1.020275/7200 seconds for LoadDataset…\n'
#             'Waited 1.523881/7200 seconds for LoadDataset…\n'
#             'Running node Input Dataset\n'
#             "Error running the node: 'full_dataset'\n"
#             '\n'
#             'Node stderr: Traceback (most recent call last):\n'
#             '  File '
#             '"/root/.cache/pypoetry/virtualenvs/uncertainty-engine-workflow-node-9TtSrW0h-py3.12/lib/python3.12/site-packages/uncertainty_engine_core/execute_node.py", '
#             'line 63, in execute_node\n'
#             '    run_output = run(inputs, context)\n'
#             '                 ^^^^^^^^^^^^^^^^^^^^\n'
#             '  File "/app/node.py", line 336, in run\n'
#             '    return Workflow(inputs, context).run()\n'
#             '           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n'
#             '  File "/app/node.py", line 309, in run\n'
#             '    self.results[dep_node][handle_name], self.results\n'
#             '    ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^\n'
#             "KeyError: 'full_dataset'\n"
#             '\n'
#             'During handling of the above exception, another exception '
#             'occurred:\n'
#             '\n'
#             'Traceback (most recent call last):\n'
#             '  File "/app/node.py", line 340, in <module>\n'
#             '    execute_node(run, Inputs, Outputs)\n'
#             '  File '
#             '"/root/.cache/pypoetry/virtualenvs/uncertainty-engine-workflow-node-9TtSrW0h-py3.12/lib/python3.12/site-packages/uncertainty_engine_core/execute_node.py", '
#             'line 66, in execute_node\n'
#             '    raise Exception(err)\n'
#             "Exception: 'full_dataset'\n",
#  'outputs': None,
#  'progress': {'Input Dataset': {'inputs': {'columns': {'node_handle': 'Input '
#                                                                       'Dataset_columns',
#                                                        'node_name': '_'},
#                                            'dataset': {'node_handle': 'full_dataset',
#                                                        'node_name': 'Load '
#                                                                     'Dataset'}},
#                                 'message': None,
#                                 'outputs': None,
#                                 'progress': None,
#                                 'status': <JobStatus.PENDING: 'pending'>},
#               'Load Dataset': {'inputs': {'file_id': {'id': '68dfc0f3e889afed3bc9427e'},
#                                           'project_id': '68dfc0b9e889afed3bc9427d'},
#                                'message': 'Job completed at 2025-10-06 '
#                                           '09:22:26.316843',
#                                'outputs': {'file': {'bucket': 'prod-uncertainty-engine-l-uncertaintyengineloaddat-3azq5xxs6mdp',
#                                                     'key': 'd7637673-3e55-4311-ade8-a1bb4f691e7d/3bce53cc-a887-4831-9bdf-223539f56dcd/content.csv'}},
#                                'progress': None,
#                                'status': <JobStatus.COMPLETED: 'completed'>},
#               'Model Config': {'inputs': {},
#                                'message': 'Job completed at 2025-10-06 '
#                                           '09:22:24.561362',
#                                'outputs': {'config': {'input_retained_dimensions': None,
#                                                       'input_variance': None,
#                                                       'kernel': None,
#                                                       'model_type': 'SingleTaskGPTorch',
#                                                       'output_retained_dimensions': None,
#                                                       'output_variance': None,
#                                                       'seed': None,
#                                                       'warp_inputs': False}},
#                                'progress': None,
#                                'status': <JobStatus.COMPLETED: 'completed'>},
#               'Output Dataset': {'inputs': {'columns': {'node_handle': 'Output '
#                                                                        'Dataset_columns',
#                                                         'node_name': '_'},
#                                             'dataset': {'node_handle': 'full_dataset',
#                                                         'node_name': 'Load '
#                                                                      'Dataset'}},
#                                  'message': None,
#                                  'outputs': None,
#                                  'progress': None,
#                                  'status': <JobStatus.PENDING: 'pending'>},
#               'Save': {'inputs': {'file': {'node_handle': 'model',
#                                            'node_name': 'Train Model'},
#                                   'fileid': {'node_handle': 'Save_fileid',
#                                              'node_name': '_'}},
#                        'message': None,
#                        'outputs': None,
#                        'progress': None,
#                        'status': <JobStatus.PENDING: 'pending'>},
#               'Train Model': {'inputs': {'config': {'node_handle': 'config',
#                                                     'node_name': 'Model '
#                                                                  'Config'},
#                                          'inputs': {'node_handle': 'input_dataset',
#                                                     'node_name': 'Load '
#                                                                  'Dataset'},
#                                          'outputs': {'node_handle': 'output_dataset',
#                                                      'node_name': 'Load '
#                                                                   'Dataset'}},
#                               'message': None,
#                               'outputs': None,
#                               'progress': None,
#                               'status': <JobStatus.PENDING: 'pending'>}},
#  'status': <JobStatus.FAILED: 'failed'>}

# %% [markdown]
# ## 3. Predicting with Trained Model

# %% [markdown]
# Since this model is saved to the cloud, we can consider how the SDK and GUI can be used together.

# %% [markdown]
# We can define a new test dataset and upload it:

# %%
x0 = np.linspace(0, 10, 50)
x1 = np.linspace(-6, 10, 50)
X0, X1 = np.meshgrid(x0, x1)
shape = X0.shape

test_inputs = {
    'x0':       X0.flatten(),
    'x1':       X1.flatten(),
}

test_outputs = make_outputs_base(pd.DataFrame(test_inputs), output_names)

# %%
upload_dataset(
    client=client,
    project_name=PROJECT_NAME,
    dataset_name='test_input',
    dataset=test_inputs
)
# Out:
# Uploaded test_input to Demos

# %% [markdown]
# The resources generated in this notebook (input datasets, trained model) are stored in the cloud. This means that they can be ran via the GUI if preferred.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Visualise Results

# %% [markdown]
# After predicting with our trained model in the cloud, we can recover the results to plot.

# %%
test_predictions = get_data(
    client=client,
    project_name=PROJECT_NAME,
    dataset_name='test_predictions'
)
test_uncertainty = get_data(
    client=client,
    project_name=PROJECT_NAME,
    dataset_name='test_uncertainty'
)

# %%
training_inputs = get_data(
    client=client,
    project_name=PROJECT_NAME,
    dataset_name=filename
)

fig, axs = plot_results_grid(
    test_inputs,
    test_predictions,
    test_uncertainty,
    test_outputs,
    training_inputs=training_inputs,
    input_cols=("x0", "x1"),
    output_cols=["y0", "y1"],   # or None to use all columns in test_outputs
    shape=None,                 # inferred automatically if omitted
    cmap=cmap_std,
    suptitle=""
)
plt.show()

# %% [markdown]
# ### Discussion
#
# In the visualised results above, good agreement was found between the ground truth and model prediction for the y0 (left hand panel) parameter but not the y1 (right hand panel). This was due to the sparse dataset in which the model was trained on. Crucially, this discrepency is exposed through the increased uncertainty in the y1 parameter.

# %% [markdown]
# ## 4. Validate Model

# %% [markdown]
# The above visualisation demonstrates the need to validate the model.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
get_node_info('PredictModel')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_node_info('PredictModel')
#
# Cell In[1], line 93, in get_node_info(node_name)
#      92 def get_node_info(node_name):
# ---> 93     nodes = client.list_nodes()
#      94     nodes_by_id = {node["id"]: node for node in nodes}
#      95     # Print the details of the node
#
# NameError: name 'client' is not defined

# %%
def validate_model_workflow(client, 
                   project_name: str,
                   dataset_name: str, 
                   input_names: list,
                   output_names: list,
                   model_name: str,
                   is_visualise_workflow: bool = False,
                   is_print_full_output: bool = False) -> dict:
    """
    A workflow that trains a machine learning model.
    Here, we assume all resources have already been uploaded to the cloud.
    :param client: The Uncertainty Engine client.
    :param project_name: The name of the project.
    :param dataset_name: The name of the dataset.
    :param input_names: The names of the input columns.
    :param output_names: The names of the output columns.
    :param model_name: The name of the trained model.
    :param is_visualise_workflow: Whether to print the workflow graph.
    :param is_print_full_output: Whether to print the full output of the workflow.
    :return: The response from running the workflow.
    """
    # 1. Create the graph
    graph = Graph()

    # 2. Create relevant nodes, handles, and add to graph:

    # 2.a. Load model config node
    load_model = Node(
        node_name="LoadModel",
        label="Load Model",
        file_id=wrap_resource_id(
            get_resource_id(
                client=client,
                project_name=project_name, 
                resource_name=model_name, 
                resource_type='model')
                ),
        project_id=get_project_id(
            client=client,
            project_name=project_name
            ),
    )
    graph.add_node(load_model)  # add to graph
    dataset = load_model.make_handle("trained_model")  # add handle
    
    # 2.b. Load dataset node
    load_data = Node(
        node_name="LoadDataset",
        label="Load Dataset",
        file_id=wrap_resource_id(
            get_resource_id(
                client=client,
                project_name=project_name, 
                resource_name=dataset_name, 
                resource_type='dataset')
                ),
        project_id=get_project_id(
            client=client,
            project_name=project_name
            ),
    )
    graph.add_node(load_data)  # add to graph
    dataset = load_data.make_handle("full_dataset")  # add handle
    
    # 2.c. Filter dataset node for inputs
    input_data = Node(
        node_name="FilterDataset",
        label="Input Dataset",
        columns=input_names,
        dataset=dataset,
    )
    graph.add_node(input_data)  # add to graph
    input_dataset = load_data.make_handle("input_dataset")  # add handle
    
    # 2.d. Filter dataset node for outputs
    output_data = Node(
        node_name="FilterDataset",
        label="Output Dataset",
        columns=output_names,
        dataset=dataset,
    )
    graph.add_node(output_data)  # add to graph
    output_dataset = load_data.make_handle("output_dataset")  # add handle
    
    # 2.e. Predict model node
    predict_model = Node(
        node_name="PredictModel",
        label="Predict Model",
        model=input_dataset,
        dataset=output_dataset,
    )
    graph.add_node(predict_model)  # add to graph
    output_model = predict_model.make_handle("model")  # add handle
    
    # 2.e. Save model node
    save = Node(
        node_name="Save",
        label="Save",
        file=output_model,
        fileid=save_model_name,
    )
    graph.add_node(save)  # add to graph

    if is_visualise_workflow:
        pprint(graph.nodes)

    workflow = Workflow(
        graph=graph.nodes,
        inputs=graph.external_input,
        external_input_id=graph.external_input_id,
        requested_output={
            }
        )

    response = client.run_node(workflow)
    if is_print_full_output:
        pprint(response.model_dump())

# %% [markdown]
# # Conclusion.

# %% [markdown]
# In this notebook, we looked at writing a train model workflow in the SDK. Cloud-based resource interaction is highlighted by subsequent prediction with the trained model in the GUI. Of course, this prediction can also be performed via the SDK alone.
#
# The SDK gives the opportunity to make bespoke plots and visualise the results. These can also be written as *nodes* such that bespoke visualisation can be displayed in either the GUI or SDK.
#
# Now model training can be done, further investigations can be made. The found lengthscales and model hyperparameters are saved in the model ready for closer inspection. Additionally, the *Model Config* node allows for changes to kernels to be made alongside input and output transformations.

# %% [markdown]
# Success? Any problems, contact [dan.greenhouse@digilab.ai](dan.greenhouse@digilab.ai) or submit a ticket at the Help Center: [get.support.uncertaintyengine.ai](get.support.uncertaintyengine.ai).
